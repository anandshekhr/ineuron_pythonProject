# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as urReq
import requests, mysql, pymongo, time, os

# %%
DRIVERPATH = r'chromedriver.exe'

# %%
def videodetails(videourl: str):
    driver = webdriver.Chrome()
    driver.get(videourl)

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.youtube.com/watch?v=3NfjY7ddHz8')

# %%
contentvideopage = driver.page_source.encode('utf-8').strip()
videopagesoup = bs(contentvideopage,'lxml')

# %%
videolikes = videopagesoup.findAll("span", class_="like-button-renderer")

# %%
videolikes
# Out:
# []

# %%
# videopagesoup

# %%
r = requests.get('https://www.youtube.com/watch?v=3NfjY7ddHz8')
s = bs(r.text, "html.parser")
likes = s.find("span", class_="like-button-renderer").span.button.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Shekhar's\Desktop\iNeuron\Python_Project_onePlus\video_details.ipynb Cell 10 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Shekhar%27s/Desktop/iNeuron/Python_Project_onePlus/video_details.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> r = requests.get('https://www.youtube.com/watch?v=3NfjY7ddHz8')
#       <a href='vscode-notebook-cell:/c%3A/Users/Shekhar%27s/Desktop/iNeuron/Python_Project_onePlus/video_details.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> s = bs(r.text, "html.parser")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Shekhar%27s/Desktop/iNeuron/Python_Project_onePlus/video_details.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> likes = s.find("span", class_="like-button-renderer").span.button.text
#
# AttributeError: 'NoneType' object has no attribute 'span'

# %%
s
# Out:
# <!DOCTYPE html>
# <html lang="en-GB" style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" system-icons="" typography="" typography-spacing=""><head><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="AsKJ0YJfrprDHN9cO+Arkwlyt0SqGVbRekp6Ho6B0zL8/aWcEEa7mYjLrXVRY4E3+ZPTupaMmCxJOtl4ava9CgAAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLCJleHBpcnkiOjE2Njk3NjYzOTksImlzU3ViZG9tYWluIjp0cnVlfQ==" http-equiv="origin-trial"/><script nonce="VgyqKjhIU1mUTgKrp5k4EQ">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else for(var k in a[0])ytcfg.d()[k]=a[0][k]}};
# ...
