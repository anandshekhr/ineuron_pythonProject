# %%
from googleapiclient.discovery import build
import pandas as pd
import pprint

# %%
api_key = "AIzaSyC7dDNkWQpzsfqMgzVcf9AU2vqW4hkgTkg"
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
class ytube_api:
    def __init__(self,link: str,apikey: str):
        self.video_id = None
        self.video_link = link
        self.details = []
        self.apiKey = apikey
        
    def extractVideoId(self):
        _id = self.video_link.split("=")
        self.video_id = _id[1]
        return self.video_id
    
    def getvideocomments(self):
        youtube = build('youtube', 'v3', developerKey=self.apiKey)
        getResult = youtube.commentThreads().list(
            part = 'snippet',videoId = self.extractVideoId(),maxResults = 100, textFormat = "plainText"
        ).execute()
        return getResult
        
    def extractfromresponses(self):
        for detail in self.getvideocomments()["items"]:
            authorname = detail["snippet"]['topLevelComment']['snippet']['authorDisplayName']
            comment = detail["snippet"]['topLevelComment']["snippet"]["textDisplay"]
            likes = detail["snippet"]['topLevelComment']["snippet"]['likeCount']
            replies = detail["snippet"]['totalReplyCount']
            details_dict = {'authorname':authorname,'comment':comment,'likes':likes,'replies':replies}
            self.details.append(details_dict)
        return self.details

# %%
ID = "3bZoB8PiXas" # Replace this YouTube video ID with your own.
url = "https://www.youtube.com/watch?v=2CRY5BYf-js"

# %%
a = ytube_api(link=url,apikey = api_key)

# %%
a.extractVideoId()
# Out:
# '2CRY5BYf-js'

# %%
a.getvideocomments()

# pprint.pprint(a.extractcommentnos())
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'yY4zBNbfVwxS-fvZZpdHJYG18c4',
#  'pageInfo': {'totalResults': 21, 'resultsPerPage': 100},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'SsABnuUarP6HCwsSU6kydcpD7FA',
#    'id': 'UgwMYTyPbpnjhriGhS54AaABAg',
#    'snippet': {'videoId': '2CRY5BYf-js',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '1Ew_W26__zBf8nibKGziQ3BOQ10',
#      'id': 'UgwMYTyPbpnjhriGhS54AaABAg',
#      'snippet': {'videoId': '2CRY5BYf-js',
#       'textDisplay': 'Today is the last day for the offering of 30% off on all the courses  @iNeuron Intelligence  . Use Krish30 as the coupon code. Happy Learning!!\r\nCheck out all the courses link below. This offer is valid till 11th September\r\nData Science Industry Ready Projects :https://bit.ly/3qmKGAe\r\n\rFSDS Bootcamp 2.0 With Job Guaranteed: https://bit.ly/3qalRaF\r\nData Science Industry Ready Projects : https://bit.ly/3qAkLVX\r\n30 Days Data Science Interview Prep: https://bit.ly/3ASKOfy\r\nJava Full stack Developer: https://bit.ly/3ei8HWa\r\nDevops Pro: https://bit.ly/3D4KI7l',
#       'textOriginal': 'Today is the last day for the offering of 30% off on all the courses  @iNeuron Intelligence  . Use Krish30 as the coupon code. Happy Learning!!\r\nCheck out all the courses link below. This offer is valid till 11th September\r\nData Science Industry Ready Projects :https://bit.ly/3qmKGAe\r\n\rFSDS Bootcamp 2.0 With Job Guaranteed: https://bit.ly/3qalRaF\r\nData Science Industry Ready Projects : https://bit.ly/3qAkLVX\r\n30 Days Data Science Interview Prep: https://bit.ly/3ASKOfy\r\nJava Full stack Developer: https://bit.ly/3ei8HWa\r\nDevops Pro: https://bit.ly/3D4KI7l',
#       'authorDisplayName': 'Krish Naik',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_Ow7V1PyNJXmvxUmamZqNR3IMT94rkYdJ0mz-8xQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCNU_lfiiWBdtULKOw6X0Dig',
#       'authorChannelId': {'value': 'UCNU_lfiiWBdtULKOw6X0Dig'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-09-11T06:20:21Z',
#       'updatedAt': '2022-09-11T06:20:21Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'zp8mla3ZDsorLm-ueJoQD2GahzY',
#    'id': 'Ugy2m9QD0FlSDwFSiG54AaABAg',
#    'snippet': {'videoId': '2CRY5BYf-js',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'BZXZY4KqsyOoDonDR--IBQLVWMs',
#      'id': 'Ugy2m9QD0FlSDwFSiG54AaABAg',
#      'snippet': {'videoId': '2CRY5BYf-js',
#       'textDisplay': 'Sir can we get job refferal if we take interview preparstion',
#       'textOriginal': 'Sir can we get job refferal if we take interview preparstion',
#       'authorDisplayName': 'satabdi sarangi',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu-s4u7z4XZkeFIxORU3yEM3oEgsIMMWOCruyOSs=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCzTIAGSLDKSLiX2azO9yZUA',
#       'authorChannelId': {'value': 'UCzTIAGSLDKSLiX2azO9yZUA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-11T10:58:44Z',
#       'updatedAt': '2022-09-11T10:58:44Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'VLfdmjwd23nIrR81qi45Ae_HO1Q',
#    'id': 'UgxPtCFuPub-6WNfGrR4AaABAg',
#    'snippet': {'videoId': '2CRY5BYf-js',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'I-hMTt6ogPmeav98OLTWh5KgYcY',
#      'id': 'UgxPtCFuPub-6WNfGrR4AaABAg',
#      'snippet': {'videoId': '2CRY5BYf-js',
#       'textDisplay': 'Hey Krishna Just want to tell  all the course content is good.But what I feel is there is no timeline allocation for each.Suppose if I am taking the course and am looking more into Data Visualization but if you go to ML initially it will be difficult',
#       'textOriginal': 'Hey Krishna Just want to tell  all the course content is good.But what I feel is there is no timeline allocation for each.Suppose if I am taking the course and am looking more into Data Visualization but if you go to ML initially it will be difficult',
#       'authorDisplayName': 'CricIn',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/PyVQN_xPvYHoDnUqZMgyLN2_pA2WwHOXz7nPseJklbpXHYYlK5kMG2ZyVhKEzIYRqLngFLrkzQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UChE5d0Qtx3rIlCJ3Z4-Yugg',
#       'authorChannelId': {'value': 'UChE5d0Qtx3rIlCJ3Z4-Yugg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-11T10:29:32Z',
#       'updatedAt': '2022-09-11T10:29:32Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'LuquldkgkS6Osp3P9Cis6qekksI',
#    'id': 'Ugzk-L_gxs8tHoYFt8F4AaABAg',
#    'snippet': {'videoId': '2CRY5BYf-js',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'vo3ug9qZ6-yK8Ff-Fo-31fyzC3E',
#      'id': 'Ugzk-L_gxs8tHoYFt8F4AaABAg',
#      'snippet': {'videoId': '2CRY5BYf-js',
#       'textDisplay': 'Please available it for free',
#       'textOriginal': 'Please available it for free',
#       'authorDisplayName': 'Pratish Dewangan',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_bdMY-vmOILRuw5Wrk3QxZXAqkEPozoO5HFbeEIw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCMs4e4j5JVthNgTZW_wTVtA',
#       'authorChannelId': {'value': 'UCMs4e4j5JVthNgTZW_wTVtA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-11T10:02:02Z',
#       'updatedAt': '2022-09-11T10:02:02Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'sUwmxyicmQ45MWRmXQAmOIHXFuk',
#    'id': 'UgwIeXgDjLLI4tWSWeZ4AaABAg',
#    'snippet': {'videoId': '2CRY5BYf-js',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '97XIgVlp6Ev5CYvsKfQOABIBay0',
#      'id': 'UgwIeXgDjLLI4tWSWeZ4AaABAg',
#      'snippet': {'videoId': '2CRY5BYf-js',
#       'textDisplay': "That's too expensive",
#       'textOriginal': "That's too expensive",
#       'authorDisplayName': 'Pratish Dewangan',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_bdMY-vmOILRuw5Wrk3QxZXAqkEPozoO5HFbeEIw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCMs4e4j5JVthNgTZW_wTVtA',
#       'authorChannelId': {'value': 'UCMs4e4j5JVthNgTZW_wTVtA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-11T10:01:32Z',
#       'updatedAt': '2022-09-11T10:01:32Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '-fb_egJpPgoapQhLj_qSdMcnan4',
#    'id': 'UgxFtwIwUpfFLmqqATx4AaABAg',
#    'snippet': {'videoId': '2CRY5BYf-js',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'yAAAfpZxcxy7s7_HPin2zWmjnAU',
#      'id': 'UgxFtwIwUpfFLmqqATx4AaABAg',
#      'snippet': {'videoId': '2CRY5BYf-js',
#       'textDisplay': 'Hello Sir,\nI made the payment to your Paypal email id. Can you please give me access to the dashboard ?',
#       'textOriginal': 'Hello Sir,\nI made the payment to your Paypal email id. Can you please give me access to the dashboard ?',
#       'authorDisplayName': 'Lori Zhuka',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_fQRcQloqDlNAHps-du9H25pk4wcAqISlrpQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCVecSyWwulSLc-LMaRFSLmw',
#       'authorChannelId': {'value': 'UCVecSyWwulSLc-LMaRFSLmw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-11T09:16:49Z',
#       'updatedAt': '2022-09-11T09:16:49Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'I2b1bOUJyyIBX4C81lHiF97xSpA',
#    'id': 'UgzaPy5wEUBOVev7l_14AaABAg',
#    'snippet': {'videoId': '2CRY5BYf-js',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'iBU3Y5N7T431CwAMBuWTVZKkun4',
#      'id': 'UgzaPy5wEUBOVev7l_14AaABAg',
#      'snippet': {'videoId': '2CRY5BYf-js',
#       'textDisplay': 'Hi krish can u give both Data science interview and data science industry grade project both combined at a  discount price?',
#       'textOriginal': 'Hi krish can u give both Data science interview and data science industry grade project both combined at a  discount price?',
#       'authorDisplayName': 'alex pandian',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_rR0V4hxsnz7GYW4yGEDtQ0vasPUilc35q9dqPJpmNH99f-86DYr2S1JyZGKRr=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCR0xOWbEKlis3Q17APIvxJQ',
#       'authorChannelId': {'value': 'UCR0xOWbEKlis3Q17APIvxJQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-11T08:54:25Z',
#       'updatedAt': '2022-09-11T08:54:25Z'}},
#     'canReply': True,
#     'totalReplyCount': 2,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'D2sG_PYs4TWjLO2YJU5p3HoXB8E',
#    'id': 'Ugxrfy2AQgZ32U5DHTh4AaABAg',
#    'snippet': {'videoId': '2CRY5BYf-js',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'mraOiwGbUHnmr42NuSqk6yHkcL8',
#      'id': 'Ugxrfy2AQgZ32U5DHTh4AaABAg',
#      'snippet': {'videoId': '2CRY5BYf-js',
#       'textDisplay': 'Duration of the course & when we become ready to apply for job ?',
#       'textOriginal': 'Duration of the course & when we become ready to apply for job ?',
#       'authorDisplayName': 'MD ASHRAF MOIN',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu-oOFWM0kFA45QKSD0ZwyUqHQ7t8hDhZgxI_SQIzg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC-7cLhZQhPl4zF6_r2ZLENw',
#       'authorChannelId': {'value': 'UC-7cLhZQhPl4zF6_r2ZLENw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-11T08:22:49Z',
#       'updatedAt': '2022-09-11T08:22:49Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'cZVK0SXAJ3lS5dIEpwwXkmEsZho',
#    'id': 'UgwH9T0RihAa7IQDMal4AaABAg',
#    'snippet': {'videoId': '2CRY5BYf-js',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '-V4nPWedPx4f493lWHnllK8CpRo',
#      'id': 'UgwH9T0RihAa7IQDMal4AaABAg',
#      'snippet': {'videoId': '2CRY5BYf-js',
#       'textDisplay': 'How the industry ready projects different from the ones already available in tech neuron? Do you teach anything additionally compared to the existing ones?',
#       'textOriginal': 'How the industry ready projects different from the ones already available in tech neuron? Do you teach anything additionally compared to the existing ones?',
#       'authorDisplayName': 'Shashi Kanth',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_Y_s9wiLe6oMzziiqIz32K-BuF3BLuPj_GEGf-DA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC5CdUht4a4zlbNN2N9Aeolw',
#       'authorChannelId': {'value': 'UC5CdUht4a4zlbNN2N9Aeolw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-11T07:43:54Z',
#       'updatedAt': '2022-09-11T07:43:54Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'tW-c7d4r0nUxIrYWz07YfJPAmus',
#    'id': 'Ugx1DfUhVX_ioAdRzCF4AaABAg',
#    'snippet': {'videoId': '2CRY5BYf-js',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'q-cY3RLk1t0BukwhWAx26sOAngg',
#      'id': 'Ugx1DfUhVX_ioAdRzCF4AaABAg',
#      'snippet': {'videoId': '2CRY5BYf-js',
#       'textDisplay': 'Hello Krish, Will the industry ready projects helpful in adding in resume or do you give any suggestions for the projects.',
#       'textOriginal': 'Hello Krish, Will the industry ready projects helpful in adding in resume or do you give any suggestions for the projects.',
#       'authorDisplayName': 'Shashi Kanth',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_Y_s9wiLe6oMzziiqIz32K-BuF3BLuPj_GEGf-DA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC5CdUht4a4zlbNN2N9Aeolw',
#       'authorChannelId': {'value': 'UC5CdUht4a4zlbNN2N9Aeolw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-11T07:41:46Z',
#       'updatedAt': '2022-09-11T07:41:46Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'UaqrN4dQJMDAS_F6LPwDuCP4r54',
#    'id': 'UgznSa4v6PZrN3RTHGV4AaABAg',
#    'snippet': {'videoId': '2CRY5BYf-js',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'rLQXSpsjz7v7veSyBsgvLNmOFKQ',
#      'id': 'UgznSa4v6PZrN3RTHGV4AaABAg',
#      'snippet': {'videoId': '2CRY5BYf-js',
#       'textDisplay': 'Sir this course is required for fsds student..I want to your suggestion...you launch the one new course end to end data science industry project.. there total 5 project in complete in 5-6 month .. this course is benefit for me... yeah fsds course is too much... Take a subscription or not.. I think both course will be start same time and when our course is end then project will be covered this  is + point....  second thing is take heavy load  for cover the both course.. this -ve point... what is your opinion???',
#       'textOriginal': 'Sir this course is required for fsds student..I want to your suggestion...you launch the one new course end to end data science industry project.. there total 5 project in complete in 5-6 month .. this course is benefit for me... yeah fsds course is too much... Take a subscription or not.. I think both course will be start same time and when our course is end then project will be covered this  is + point....  second thing is take heavy load  for cover the both course.. this -ve point... what is your opinion???',
#       'authorDisplayName': 'Mukul Singh',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu9aTgYYHXCOrPk2SYWHcZr6HNsv49njstlxz_i0Dw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCwEYDkVn6GbdQQj9Sojwomw',
#       'authorChannelId': {'value': 'UCwEYDkVn6GbdQQj9Sojwomw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-09-11T07:31:55Z',
#       'updatedAt': '2022-09-11T07:31:55Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'o-NLwZXyD4vQ9zS5nV5TigIPJL0',
#    'id': 'Ugz1yzjwZeUPGPrhWeh4AaABAg',
#    'snippet': {'videoId': '2CRY5BYf-js',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'NwEnBVD-3y2z_uHb2N3_Bheij7Q',
#      'id': 'Ugz1yzjwZeUPGPrhWeh4AaABAg',
#      'snippet': {'videoId': '2CRY5BYf-js',
#       'textDisplay': 'data science industrial projects are covered in fsds batch or not?',
#       'textOriginal': 'data science industrial projects are covered in fsds batch or not?',
#       'authorDisplayName': 'Gursimran Singh',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu96z8Pk23FcmEKSjm1vWUr81mHYs1Xtvf90SVqe114=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCMyh8cXEPbw53LJa7DeAqvg',
#       'authorChannelId': {'value': 'UCMyh8cXEPbw53LJa7DeAqvg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-11T07:21:26Z',
#       'updatedAt': '2022-09-11T07:21:26Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'W5HD_1DgGPJMqKxx07QmXHqg_cs',
#    'id': 'UgzsHmwqZgLQOyiiSn14AaABAg',
#    'snippet': {'videoId': '2CRY5BYf-js',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'OS-HiWq1dRckPBVMkjkMds1ybc4',
#      'id': 'UgzsHmwqZgLQOyiiSn14AaABAg',
#      'snippet': {'videoId': '2CRY5BYf-js',
#       'textDisplay': '❤Only for fans over 18 year⤵️ Alles sehr schön. Aber zuerst zusammen die Nummern 10 und 1. Eine gedangsiemm.ONLINE Brünette und eine andere Blondine. Es wäre unfair, wennj ich 4 wählen würde',
#       'textOriginal': '❤Only for fans over 18 year⤵️ Alles sehr schön. Aber zuerst zusammen die Nummern 10 und 1. Eine gedangsiemm.ONLINE Brünette und eine andere Blondine. Es wäre unfair, wennj ich 4 wählen würde',
#       'authorDisplayName': 'davo dl',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu90xMLwrGbRyRdtu56pWuXH9cpTE8LlmLYaWHa1Ah0wdUkGxIJ4prZj1o1CEXAP=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC4KZwAODBZn0qaZQSU3lLuw',
#       'authorChannelId': {'value': 'UC4KZwAODBZn0qaZQSU3lLuw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-11T07:11:33Z',
#       'updatedAt': '2022-09-11T07:11:33Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'JidiNFgmCiY06QWUlMPSMVHY7wo',
#    'id': 'UgxVpaWpToZEs47FnC14AaABAg',
#    'snippet': {'videoId': '2CRY5BYf-js',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'bZ8UEtHV1VHLcqE2Of52LbEUfOI',
#      'id': 'UgxVpaWpToZEs47FnC14AaABAg',
#      'snippet': {'videoId': '2CRY5BYf-js',
#       'textDisplay': 'Hi Krish.. if these courses will be available on Tech Neuron?',
#       'textOriginal': 'Hi Krish.. if these courses will be available on Tech Neuron?',
#       'authorDisplayName': 'education 4all',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu-xH-0lRBkrBZfwGKUxXd-GMr_vnpQIuIaUCA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCGVscgv2j01pOAgT1I4oJxw',
#       'authorChannelId': {'value': 'UCGVscgv2j01pOAgT1I4oJxw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-11T07:03:14Z',
#       'updatedAt': '2022-09-11T07:03:14Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'b-H-WQw2eZxKEoa1YqhaVB_Vdp4',
#    'id': 'UgyoU1uGxq8D3iEDvMp4AaABAg',
#    'snippet': {'videoId': '2CRY5BYf-js',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'pUJqEKuO9oeyhiqWhK-8MvyP_kE',
#      'id': 'UgyoU1uGxq8D3iEDvMp4AaABAg',
#      'snippet': {'videoId': '2CRY5BYf-js',
#       'textDisplay': 'Sir iam believing in you     are you going to lecture in full stack data science live then I will join iam believing in you sir please reply as fast as possible to join today sir❤️❤️❤️ \n\nWhat are the lecture you going this course please do video iam only wanted to see your video sir',
#       'textOriginal': 'Sir iam believing in you     are you going to lecture in full stack data science live then I will join iam believing in you sir please reply as fast as possible to join today sir❤️❤️❤️ \n\nWhat are the lecture you going this course please do video iam only wanted to see your video sir',
#       'authorDisplayName': 'Rajesh Srirangam',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu8kwVmqCFPukmPaxY_oBCYpkDRpXCl3m1HQxw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCcbDkP0kAJi_Tudj2SMxcsA',
#       'authorChannelId': {'value': 'UCcbDkP0kAJi_Tudj2SMxcsA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-11T07:02:21Z',
#       'updatedAt': '2022-09-11T07:04:59Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'IlvUP0B-p8F3hTASYMKl9VcJkRc',
#    'id': 'Ugx8txZiYvBgzF_UPTh4AaABAg',
#    'snippet': {'videoId': '2CRY5BYf-js',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'FdGnfuVHMLKOIRgtTUqGtTjw_W8',
#      'id': 'Ugx8txZiYvBgzF_UPTh4AaABAg',
#      'snippet': {'videoId': '2CRY5BYf-js',
#       'textDisplay': 'Will these courses be available in tech neuron??',
#       'textOriginal': 'Will these courses be available in tech neuron??',
#       'authorDisplayName': 'Deep s',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_6w6oeaYNmlLDq30GHOsNIgRsq5t38CZ4e7A=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCgOm6Co7fy2QK2g0yvu0TjA',
#       'authorChannelId': {'value': 'UCgOm6Co7fy2QK2g0yvu0TjA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-11T06:45:48Z',
#       'updatedAt': '2022-09-11T06:45:48Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'hw7AWgMKX52-2Ll89yQPm17l6mU',
#    'id': 'UgwAChNjPrwtUEFhOPJ4AaABAg',
#    'snippet': {'videoId': '2CRY5BYf-js',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'gu22_qIXIrpneVX3_2YJSWV9uQg',
#      'id': 'UgwAChNjPrwtUEFhOPJ4AaABAg',
#      'snippet': {'videoId': '2CRY5BYf-js',
#       'textDisplay': 'Hello krish sir i want to join this course but after 20th september is it possible to join late into the course',
#       'textOriginal': 'Hello krish sir i want to join this course but after 20th september is it possible to join late into the course',
#       'authorDisplayName': 'Ankita Deshpande',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu8QqGOO06jyxuu9QV7DVoFu-eO2-zbu7JiThQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCihZyb1vkb5fZhwoBmlG9IA',
#       'authorChannelId': {'value': 'UCihZyb1vkb5fZhwoBmlG9IA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-11T06:40:22Z',
#       'updatedAt': '2022-09-11T06:40:22Z'}},
#     'canReply': True,
#     'totalReplyCount': 3,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '7HSBKTfWhESc7cY_JWOlXwLuLoA',
#    'id': 'UgzImsyvBmgd129cbNR4AaABAg',
#    'snippet': {'videoId': '2CRY5BYf-js',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Dyhy7RfO6ZzpQsgfJp8Ft130QgU',
#      'id': 'UgzImsyvBmgd129cbNR4AaABAg',
#      'snippet': {'videoId': '2CRY5BYf-js',
#       'textDisplay': "Hello sir, \nI want to enroll FSDS 2.O but i have a doubt as you say for november batch deep learning is going on. But it's 4 th module in FSDS.. So how much time it take to complete at 40%   of the Modules.",
#       'textOriginal': "Hello sir, \nI want to enroll FSDS 2.O but i have a doubt as you say for november batch deep learning is going on. But it's 4 th module in FSDS.. So how much time it take to complete at 40%   of the Modules.",
#       'authorDisplayName': 'SAEED SHAIKH',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/Vhkd-8MHI9-OxIn4uv3WJAU358AGh986L_Z5mg5MKA1ND3e1EkGPRc-JNTNVN5r5COAT8PfZqJk=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCoEojg6IUbkyJYRrVjJKkVg',
#       'authorChannelId': {'value': 'UCoEojg6IUbkyJYRrVjJKkVg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-11T06:28:33Z',
#       'updatedAt': '2022-09-11T06:28:33Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '2PGA_pQSrHZm1eT1WwVEjozIch0',
#    'id': 'UgyZAQKI8d1ipup3Pd14AaABAg',
#    'snippet': {'videoId': '2CRY5BYf-js',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'oM_cN4hbo7sZt-RdVzwM6HsbLHY',
#      'id': 'UgyZAQKI8d1ipup3Pd14AaABAg',
#      'snippet': {'videoId': '2CRY5BYf-js',
#       'textDisplay': "Hi Krish, important query! I'm from bca +MBA background, having experience  3+years of experience in sales and marketing. I wanna switch to data domain (analysis and science). Which course is best for me in I neuron 🙏",
#       'textOriginal': "Hi Krish, important query! I'm from bca +MBA background, having experience  3+years of experience in sales and marketing. I wanna switch to data domain (analysis and science). Which course is best for me in I neuron 🙏",
#       'authorDisplayName': 'aditya tapi',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu8fyXOhzRB8_3wYwy4zs3uTsNF_XkGgz1lNrA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCYd9525WS6rsZHWgH1WjG7g',
#       'authorChannelId': {'value': 'UCYd9525WS6rsZHWgH1WjG7g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 4,
#       'publishedAt': '2022-09-11T06:25:50Z',
#       'updatedAt': '2022-09-11T06:26:17Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'DRSza6JYtytPx5AuSp8jEtmlZdE',
#    'id': 'UgzDVg4JWpOiUiuaWXh4AaABAg',
#    'snippet': {'videoId': '2CRY5BYf-js',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'o7ZBOOFY7z10s2Lvz5nJehebWwQ',
#      'id': 'UgzDVg4JWpOiUiuaWXh4AaABAg',
#      'snippet': {'videoId': '2CRY5BYf-js',
#       'textDisplay': 'Hello, could you please add an NLP project too? For data science industry ready projects.',
#       'textOriginal': 'Hello, could you please add an NLP project too? For data science industry ready projects.',
#       'authorDisplayName': 'srinidhi karjol',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_gEyssFzSIuP2B7zQm531iLlsJZ5QTXaiX8asreQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC_TGo5XNN3GE7He_xewBm2A',
#       'authorChannelId': {'value': 'UC_TGo5XNN3GE7He_xewBm2A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-11T06:20:14Z',
#       'updatedAt': '2022-09-11T06:20:14Z'}},
#     'canReply': True,
#     'totalReplyCount': 2,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '-pFQQtRooXkBGoimZyHwo0oSMyE',
#    'id': 'UgyjbBsYyUWNQ3HkwGx4AaABAg',
#    'snippet': {'videoId': '2CRY5BYf-js',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'U3OqOHinoQtrZFonPCHbFdpu6dk',
#      'id': 'UgyjbBsYyUWNQ3HkwGx4AaABAg',
#      'snippet': {'videoId': '2CRY5BYf-js',
#       'textDisplay': 'Thank you sir',
#       'textOriginal': 'Thank you sir',
#       'authorDisplayName': 'Arise Awake',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu-Or9R4_QGZE0SCh_RkGHDXSA2PTNmO7rOhlcxu5g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCKwp_an4C7-ydViLibFSO9Q',
#       'authorChannelId': {'value': 'UCKwp_an4C7-ydViLibFSO9Q'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-11T06:19:32Z',
#       'updatedAt': '2022-09-11T06:19:32Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %%
df = pd.DataFrame(a.extractfromresponses())

# %%
df
# Out:
#           authorname                                            comment  \
# 0       Dhruv Rathee  This video focuses mostly on British expansion...
# 1           m.mmmmmm                                          Wow sir 🥳
# 2      MAYANK PANDIT  We can and read by ourselves, and you are not ...
# 3      Hunny Balotia       Maratha and mysore vs british ki video banao
# 4      Anup Bankapur                                Woow just amazing 👏
# ..               ...                                                ...
# 94          Nirav G.                                 Amazing details 👌👍
# 95  Ramyajeet Sanyal  I have read all these things in my school's hi...
# 96         অ ভি দী প                           Very informative video 💖
# 97        info Shock                         Very informative, thanks 👌
# 98       Pussykiller  10:34 error in naming Ahmed Shah Durrani as Na...
#
#     likes  replies
# 0    2095      361
# 1       0        0
# 2       0        0
# 3       1        0
# 4       0        0
# ..    ...      ...
# 94      0        0
# 95      0        0
# 96      0        0
# 97      0        0
# 98      0        0
#
# [99 rows x 4 columns]
